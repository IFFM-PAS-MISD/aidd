# %%
import os
from IPython.display import Image, display
from tensorflow.keras.preprocessing.image import load_img
import PIL
from PIL import ImageOps
from PIL import Image
import re
import numpy as np
import tensorflow as tf
import keras
from keras import layers
from tensorflow.python.client import device_lib
import random
from tensorflow.keras.models import Model
from keras.models import load_model
import matplotlib.pyplot as plt
import matplotlib
import cv2
import csv
from matplotlib.cm import ScalarMappable

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '1'

# %%
os.chdir('/home/aijjeh/Desktop/Phd_Project/Full_wavefield_frames_time_series_project/AE_exp_results_frames_24_512_512/CFRP_teflon_3o_375_375p_50kHz_5HC_x12_15Vpp')

# %%
img = Image.open('RMS_CFRP_teflon_3o_375_375p_50kHz_5HC_ijjeh_cmap_viridis.png').convert('L')
img.save('RMS_CFRP_teflon_3o_375_375p_50kHz_5HC_ijjeh_cmap_viridis_greyscale.png')

# %%
img = plt.imread('RMS_CFRP_teflon_3o_375_375p_50kHz_5HC_ijjeh_cmap_viridis_greyscale.png',1)
print(img.shape)
# Out:
# (2400, 2400)

# %%
ret, thresholded = cv2.threshold(img, 0.5, 1.0, cv2.THRESH_BINARY)

# %%
############################################################################################################
plt.figure(figsize=(5 / 2.54, 5 / 2.54), dpi=600)
plt.gca().set_axis_off()
plt.axis('off')
plt.subplots_adjust(left=0.0, bottom=0.0, right=1, top=1.0, wspace=0.0, hspace=0.0)
plt.margins(0, 0)
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
# #############################################################################################################

plt.imshow(thresholded, cmap='viridis')
plt.savefig('RMS_CFRP_teflon_3o_375_375p_50kHz_5HC_ijjeh_cmap_viridis_greyscale_THRESHOLDED.svg',bbox_inches='tight', transparent="True", pad_inches=0)
plt.show()
