# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import cv2
import csv
import pandas as pd
import plotly.express as px

# %%
# os.chdir('/home/aijjeh/Desktop/Phd_Projects/Sequence_prediction/Full_wavefield_frames_time_series_project/AE_exp_results_frames_24_512_512/CSV_FILES_SPECIMEN_2_3_4')
# csv_saeed = 'L3_S4_B_333x333p_50kHz_5HC_18Vpp_x10_pzt_saeed_.csv'
# df_1 = pd.read_csv(csv_saeed, sep=',')
# 


os.chdir('/home/aijjeh/Desktop/Phd_Projects/Sequence_prediction/Full_wavefield_frames_time_series_project/AE_exp_results_frames_24_512_512')

csv_ijjeh_SR = 'output.csv'

df_1 =np.genfromtxt(csv_ijjeh_SR, delimiter=",", names=["x", "y"])
# pd.read_csv('L3_S4_B_333x333p_50kHz_10HC_18Vpp_x10_pzt_Ijjeh_SR_.csv', header=None).T.to_csv('output_1.csv', header=False, index=False)

df_2 =np.genfromtxt('output_1.csv', delimiter=",", names=["x", "y"])
plt.figure(figsize=(15,7))
plt.plot(df_1['x'], df_1['y'])
plt.plot(df_2['x'], df_2['y'])
plt.show()

# %%
font = {'family' : 'Times',
        'weight' : 'normal',
        'size'   : 6}

plt.rc('font', **font)

# %%
###################################################
font = {'fontname':'Times New Roman',
        'weight' : 'normal',
        'size'   : 6}

###################################################

fig, ax = plt.subplots(1,1,figsize=(10 / 2.54, 5 / 2.54), dpi=600)
matplotlib.rcParams.update({'font.size': 6})
plt.rcParams["font.family"] = "Times New Roman"


plt.axis('on')
# plt.subplots_adjust(left=0.1, bottom=0.0, right=1, top=1.0, wspace=0.1, hspace=0.1)
plt.margins(0.05, 0.05)


# x1 = (df_1['centre_window'])
# ax.plot(x1, df_1['iou'],linewidth=0.75)

ax.plot(df_2['iou'], df_2['centre_window'],linewidth=0.75)

# ax.legend(['Model-1 : window size = 64 frames', 'Model-2 : window size = 24 frames'],
#            loc='best', 
#           fancybox=True,
#          prop={'size': 4})
ax.grid()
ax.set_xlabel('Centre of the window')
ax.set_ylabel('IoU')

os.chdir('/home/aijjeh/Desktop/Phd_Project/Full_wavefield_frames_time_series_project/AE_exp_results_frames_24_512_512/CSV_FILES_SPECIMEN_2_3_4/')

plt.savefig("L3_S4_B_333x333p_50kHz_5HC_18Vpp_x10_pzt_svg_SR_ijjeh.svg") #,bbox_inches='tight', transparent="True", pad_inches=0)

# %%
############################################################################################################
plt.figure(figsize=(10 / 2.54, 5 / 2.54), dpi=600)
# plt.gca().set_axis_off()
plt.axis('on')
plt.subplots_adjust(left=0.0, bottom=0.0, right=1, top=1.0, wspace=0.0, hspace=0.0)
plt.margins(0, 0)
# plt.gca().xaxis.set_major_locator(plt.NullLocator())
# plt.gca().yaxis.set_major_locator(plt.NullLocator())
############################################################################################################
x = np.arange(0,len(df.frame),1)
y = df.iou

# plt.rcParams["figure.autolayout"] = True

plt.xlabel('Starting window of frames')
plt.ylabel('IoU')
plt.plot(x, y,color='blue', label='IoU value')
plt.legend()
plt.savefig('IoU_CFRP_teflon_30_375_375_50kHz.png')
# plt.xlim([0,231])
# plt.ylim([0,0.5])
plt.show()
plt.close('all')

# %%
os.chdir('/home/aijjeh/Desktop/Phd_Project/Full_wavefield_frames_time_series_project/AE_exp_results_frames_24_512_512/')
