# %% [raw]
# # ============================================
# __title__ = 'Autoencoder-ConvLSTM model for semantic segmentation \Delaminations identification in CFRP'
# __author__ = "Abdalraheem A. Ijjeh"
# __maintainer__ = "Abdalraheem A. Ijjeh"
# __email__ = "aijjeh@imp.gda.pl"
# # ============================================

# %%
import os
from IPython.display import Image, display
from tensorflow.keras.preprocessing.image import load_img
import PIL
from PIL import ImageOps
import re
import numpy as np
import tensorflow as tf
import keras
from keras import layers
from keras.layers import MaxPooling3D, \
    Input, ConvLSTM2D, UpSampling2D, \
    MaxPooling2D, Conv2D, Concatenate, Conv3D, \
    Dropout, BatchNormalization, Add, MaxPool2D, Conv2DTranspose, MaxPool3D, Conv3DTranspose, UpSampling3D, \
    concatenate, MaxPooling3D, Bidirectional, TimeDistributed 
from tensorflow.python.client import device_lib
import random
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from keras import backend as K 
import neptune
from keras.callbacks import Callback
# Out:
# 2021-12-11 10:26:54.794542: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Using TensorFlow backend.

# %%
########################################################################################################################
# Link to neptune ai for monitoring
########################################################################################################################
run = neptune.init(project_qualified_name='abdalraheem.ijjeh/aidd',
                   api_token='hidden')
neptune.create_experiment('Autoencoder final version for paper MSSP3')
neptune.append_tag('Monitoring loss and metrtics for MSSP3 reviewers')
# Out:
# https://app.neptune.ai/abdalraheem.ijjeh/aidd/e/SAN-3331

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '2'
# print(device_lib.list_local_devices())

# %%
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# %%
input_dir = "/aijjeh_odroid_sensors/aidd/data/raw/num/wavefield_dataset2_bottom_out/"
target_dir = "/home/aijjeh/Desktop/Phd_Projects/dataset2_labels_out"
my_list = os.listdir(input_dir)
my_list.sort(key=natural_keys)
# print(my_list)

# %%
print(len(my_list))
# Out:
# 475

# %%
height = 512
width =  512
img_size = (height, width)
num_classes = 2
batch_size = 1
time_stamps =  24
num_filters = 24
filter_size = 3
dropout_rate = 0.2
epochs = 100
input_img_paths_total = [None]*380

# %%
for i in range(380):
    input_dir = "/aijjeh_odroid_sensors/aidd/data/raw/num/wavefield_dataset2_bottom_out/" +'%d_output' % (i+1) #str(my_list[i])
    input_img_paths = sorted( 
        [
            os.path.join(input_dir, fname) 
            for fname in os.listdir(input_dir)    
            if fname.endswith(".png")
        ] 
    )
    input_img_paths.sort(key=natural_keys)
    input_img_paths_total[i] = input_img_paths

# %%
Image(input_img_paths_total[379][511])

# %%
target_img_paths = sorted(
    [
        os.path.join(target_dir, fname)
        for fname in os.listdir(target_dir)
        if fname.endswith(".png") and not fname.startswith(".")
    ]
)
target_img_paths.sort(key=natural_keys)

# %%
print(len(target_img_paths))
# print(target_img_paths)
# Out:
# 380

# %%
print("Number of samples:", len(input_img_paths_total))
# Out:
# Number of samples: 380

# %%
class Full_wavefield_frames(keras.utils.Sequence):
    def __init__(self, batch_size, img_size, input_img_paths_total_, target_img_paths_, time_stamps):
        self.batch_size = batch_size
        self.img_size = img_size
        self.input_img_paths_total = input_img_paths_total_
        self.target_img_paths = target_img_paths_
        self.time_stamps = time_stamps
    def __len__(self):
        return len(self.target_img_paths) // self.batch_size

    def __getitem__(self, idx):
        """Returns tuple (input, target) correspond to batch #idx."""
        i = idx * self.batch_size        
        batch_input_img_paths = self.input_img_paths_total[i:i+self.batch_size]      
        batch_target_img_paths = self.target_img_paths[i:i+self.batch_size] 
        
        x = np.zeros((self.batch_size,) + (self.time_stamps,) + self.img_size + (1,), dtype="float16") #  
        
        for batch_num in range(self.batch_size):
            batch_input_img_paths = batch_input_img_paths[batch_num][file_frame[i]:file_frame[i]+self.time_stamps] 
            for j, path in enumerate(batch_input_img_paths):
                img = load_img(path, target_size=self.img_size, color_mode="grayscale")            
                img = np.expand_dims(img,2)
                img = img / 255.0
                x[batch_num][j] = img
        y = np.zeros((self.batch_size,) + self.img_size + (1,), dtype="float16")
        for j, path in enumerate(batch_target_img_paths):
            img = load_img(path, target_size=self.img_size, color_mode="grayscale")            
            img = np.expand_dims(img, 2)
            img = img / 255.0
            y[j] = img
                # Ground truth labels are 1, 2, 3. Subtract one to make them 0, 1, 2:
                # y[j] -= 1
        return x, y

# %%
os.chdir('/home/aijjeh/Desktop/Phd_Projects/Sequence_prediction/Full_wavefield_frames_time_series_project/Datasets/label_set')

# %%
file_frame = np.load('frames_initial.npy')
file_frame = file_frame[:380]

# %%
print(len(file_frame))
# Out:
# 380

# %%
# Split our img paths into a training and a validation set
val_samples = int(0.20*len(my_list))
# random.Random(1337).shuffle(input_img_paths_total)
# random.Random(1337).shuffle(target_img_paths)
train_input_img_paths = input_img_paths_total[:-val_samples]
train_target_img_paths = target_img_paths[:-val_samples]
val_input_img_paths = input_img_paths_total[-val_samples:]
val_target_img_paths = target_img_paths[-val_samples:]

print(len(train_input_img_paths))

# Instantiate data Sequences for each split
train_gen = Full_wavefield_frames(batch_size, img_size, train_input_img_paths, train_target_img_paths, time_stamps)
val_gen = Full_wavefield_frames(batch_size, img_size, val_input_img_paths, val_target_img_paths, time_stamps)

print(len(train_gen))
print('1st axis',len(train_gen[0]))
print('2nd axis',len(train_gen[0][0]))
print('3rd axis',len(train_gen[0][0][0]))
print('4th axis',len(train_gen[0][0][0][0]))
print('5th axis',len(train_gen[0][0][0][0][0]))
print('6th axis',len(train_gen[0][0][0][0][0][0]))

print(np.shape(train_gen[0][1]))
# Out:
# 285
# 285
# 1st axis 2
# 2nd axis 1
# 3rd axis 24
# 4th axis 512
# 5th axis 512
# 6th axis 1
# (1, 512, 512, 1)

# %%
def normalize_batch(bn_input):
    return keras.layers.BatchNormalization()(bn_input)

# %%
def get_time_distributed(time_input, n_filters):
    x = TimeDistributed(Conv2D(filters=n_filters,
                               kernel_size=(3, 3),
                               strides=1, padding='same',
                               activation='relu'))(time_input)
    return x

# %%
def jaccard_index(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.abs(y_true) + K.abs(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %%
def get_model(img_size, num_classes):
    inputs = Input(shape = ((time_stamps,)+ img_size + (1,)))    
    ####################################################################################################################
    c11 = get_time_distributed(inputs, num_filters)
    BN = normalize_batch(c11)
    c12 = get_time_distributed(BN, num_filters)
    BN1 = normalize_batch(c12)
    d1 = TimeDistributed(MaxPool2D((2, 2), strides=(2, 2)))(BN1)
    d1 = keras.layers.Dropout(dropout_rate)(d1)
    ####################################################################################################################
    c21 = get_time_distributed(d1, num_filters*2)
    BN = normalize_batch(c21)
    c22 = get_time_distributed(BN, num_filters*2)
    BN2 = normalize_batch(c22)
    d2 = TimeDistributed(MaxPool2D((2, 2), strides=(2, 2)))(BN2)
    d2 = keras.layers.Dropout(dropout_rate)(d2)
    ####################################################################################################################
    c31 = get_time_distributed(d2, num_filters*3)
    BN = normalize_batch(c31)
    c32 = get_time_distributed(BN, num_filters*3)
    BN3 = normalize_batch(c32)
    d3 = TimeDistributed(MaxPool2D((2, 2), strides=(2, 2)))(BN3)
    d3 = keras.layers.Dropout(dropout_rate)(d3)
    ####################################################################################################################
    c41 = get_time_distributed(d3, num_filters*4)
    BN = normalize_batch(c41)
    c42 = get_time_distributed(BN, num_filters*4)
    BN4 = normalize_batch(c42)
    d4 = TimeDistributed(MaxPool2D((2, 2), strides=(2, 2)))(BN4)
    d4 = keras.layers.Dropout(dropout_rate)(d4)
    ####################################################################################################################
    # bottleneck layer
    ##################################################################################################
    c51 = get_time_distributed(d4, num_filters*5)
    BN = normalize_batch(c51)
    c52 = get_time_distributed(BN, num_filters*5)
    BN = normalize_batch(c52)
    ####################################################################################################################
    # Up sampling convolution followed by ConvTranspose
    ####################################################################################################################
    u1 = TimeDistributed(UpSampling2D((2, 2)))(BN)
    skip4 = concatenate([BN4, u1])
    skip4 = keras.layers.Dropout(dropout_rate)(skip4)  # adding dropout layer
    c61 = get_time_distributed(skip4, num_filters*4)
    BN = normalize_batch(c61)
    c62 = get_time_distributed(BN, num_filters*4)
    BN = normalize_batch(c62)
    ####################################################################################################################
    u2 = TimeDistributed(UpSampling2D((2, 2)))(BN)
    skip3 = concatenate([BN3, u2])
    skip3 = keras.layers.Dropout(dropout_rate)(skip3)
    c71 = get_time_distributed(skip3, num_filters*3)
    BN = normalize_batch(c71)
    c72 = get_time_distributed(BN, num_filters*3)
    BN = normalize_batch(c72)
    ####################################################################################################################
    u3 = TimeDistributed(UpSampling2D((2, 2)))(BN)
    skip2 = concatenate([BN2, u3])
    skip2 = keras.layers.Dropout(dropout_rate)(skip2)
    c81 = get_time_distributed(skip2, num_filters*2)
    BN = normalize_batch(c81)
    c82 = get_time_distributed(BN, num_filters*2)
    BN = normalize_batch(c82)
    ####################################################################################################################
    u4 = TimeDistributed(UpSampling2D((2, 2)))(BN)
    skip1 = concatenate([BN1, u4])
    skip1 = keras.layers.Dropout(dropout_rate)(skip1)
    c91 = get_time_distributed(skip1, num_filters)
    BN = normalize_batch(c91)
    c92 = get_time_distributed(BN, num_filters)
    BN = normalize_batch(c92)
    ####################################################################################################################
    lstm_layer = ConvLSTM2D(24, (3, 3), padding='same', return_sequences=False)(BN)
    ####################################################################################################################
    # Output layer
    output = Conv2D(1, (1, 1), activation='sigmoid')(lstm_layer)
    #################################################################################################################### 
    model_ = Model(inputs=inputs, outputs=output)
    ####################################################################################################################
    return model_
# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Build model
model = get_model(img_size, num_classes)
model.summary()
# Out:
# 2021-12-11 10:27:16.495181: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-12-11 10:27:16.497246: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-12-11 10:27:16.534028: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:86:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-12-11 10:27:16.534072: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-11 10:27:16.537994: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-12-11 10:27:16.538087: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-12-11 10:27:16.539887: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-12-11 10:27:16.540266: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-12-11 10:27:16.542183: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-12-11 10:27:16.542963: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-12-11 10:27:16.543268: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-12-11 10:27:16.547920: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-12-11 10:27:16.549130: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-11 10:27:16.550737: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-12-11 10:27:16.553118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:86:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-12-11 10:27:16.553145: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-11 10:27:16.553171: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-12-11 10:27:16.553185: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-12-11 10:27:16.553199: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-12-11 10:27:16.553213: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-12-11 10:27:16.553226: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-12-11 10:27:16.553240: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-12-11 10:27:16.553253: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-12-11 10:27:16.557756: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-12-11 10:27:16.557794: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-11 10:27:17.398511: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-12-11 10:27:17.398575: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-12-11 10:27:17.398588: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-12-11 10:27:17.405746: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 30128 MB memory) -> physical GPU (device: 0, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:86:00.0, compute capability: 7.0)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 24, 512, 512 0
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 24, 512, 512, 240         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 24, 512, 512, 96          time_distributed[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 24, 512, 512, 5208        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 24, 512, 512, 96          time_distributed_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 24, 256, 256, 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 24, 256, 256, 0           time_distributed_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 24, 256, 256, 10416       dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 24, 256, 256, 192         time_distributed_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 24, 256, 256, 20784       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 24, 256, 256, 192         time_distributed_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 24, 128, 128, 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 24, 128, 128, 0           time_distributed_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (None, 24, 128, 128, 31176       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 24, 128, 128, 288         time_distributed_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 24, 128, 128, 46728       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 24, 128, 128, 288         time_distributed_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 24, 64, 64, 7 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 24, 64, 64, 7 0           time_distributed_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 24, 64, 64, 9 62304       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 24, 64, 64, 9 384         time_distributed_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (None, 24, 64, 64, 9 83040       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 24, 64, 64, 9 384         time_distributed_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (None, 24, 32, 32, 9 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 24, 32, 32, 9 0           time_distributed_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (None, 24, 32, 32, 1 103800      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 24, 32, 32, 1 480         time_distributed_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (None, 24, 32, 32, 1 129720      batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 24, 32, 32, 1 480         time_distributed_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (None, 24, 64, 64, 1 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 24, 64, 64, 2 0           batch_normalization_7[0][0]
#                                                                  time_distributed_14[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 24, 64, 64, 2 0           concatenate[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (None, 24, 64, 64, 9 186720      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 24, 64, 64, 9 384         time_distributed_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 24, 64, 64, 9 83040       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 24, 64, 64, 9 384         time_distributed_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 24, 128, 128, 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 24, 128, 128, 0           batch_normalization_5[0][0]
#                                                                  time_distributed_17[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 24, 128, 128, 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 24, 128, 128, 108936      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 24, 128, 128, 288         time_distributed_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 24, 128, 128, 46728       batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 24, 128, 128, 288         time_distributed_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (None, 24, 256, 256, 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 24, 256, 256, 0           batch_normalization_3[0][0]
#                                                                  time_distributed_20[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 24, 256, 256, 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (None, 24, 256, 256, 51888       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 24, 256, 256, 192         time_distributed_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 24, 256, 256, 20784       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 24, 256, 256, 192         time_distributed_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 24, 512, 512, 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 24, 512, 512, 0           batch_normalization_1[0][0]
#                                                                  time_distributed_23[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 24, 512, 512, 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (None, 24, 512, 512, 15576       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 24, 512, 512, 96          time_distributed_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (None, 24, 512, 512, 5208        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 24, 512, 512, 96          time_distributed_25[0][0]
# __________________________________________________________________________________________________
# conv_lst_m2d (ConvLSTM2D)       (None, 512, 512, 24) 41568       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 512, 512, 1)  25          conv_lst_m2d[0][0]
# ==================================================================================================
# Total params: 1,058,689
# Trainable params: 1,056,289
# Non-trainable params: 2,400
# __________________________________________________________________________________________________

# %%
print(train_input_img_paths[0][0])
img = train_gen[0][0][0]
plt.imshow((img[0]*255).astype(np.uint8), cmap='Greys')
plt.show()
display(img.shape)
# Out:
# /aijjeh_odroid_sensors/aidd/data/raw/num/wavefield_dataset2_bottom_out/1_output/1_flat_shell_Vz_1_500x500bottom.png
# (24, 512, 512, 1)

# %%
def get_jaccard_index(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.abs(y_true) + K.abs(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %%
# Configure the model for training.
# We use the "sparse" version of categorical_crossentropy
# because our target data is integers.
model.compile(optimizer='adam', 
              loss='binary_crossentropy', 
              metrics=[get_jaccard_index])

callbacks = [
    keras.callbacks.ModelCheckpoint("oxford_segmentation_%d_version_10_12_2021.h5" % time_stamps, save_best_only=True)
]
class MonitoringCallback(Callback):
    def on_epoch_end(self, epoch, logs={}):
        for metric_name, metric_value in logs.items():
            neptune.log_metric(metric_name, metric_value)


# Train the model, doing validation at the end of each epoch.
model.fit(train_gen, epochs=epochs, validation_data=val_gen, callbacks=[MonitoringCallback(), callbacks])  # 

os.chdir('/home/aijjeh/Desktop/Phd_Projects/Sequence_prediction/Sequence_to_sequence/h5_models/')
model.save("UNet_Xception_style_model_%d_version_10_12_2021.h5" % time_stamps )
# Out:
# 2021-12-11 10:27:19.772231: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-12-11 10:27:19.773280: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2100000000 Hz
# Epoch 1/100
# 2021-12-11 10:27:27.395115: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-12-11 10:27:29.441694: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-12-11 10:27:29.845718: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-12-11 10:27:32.307324: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.70GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-12-11 10:27:32.307416: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.70GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 285/285 [==============================] - 324s 1s/step - loss: 0.0672 - get_jaccard_index: 0.9627 - val_loss: 0.0148 - val_get_jaccard_index: 0.9980
# Epoch 2/100
# 285/285 [==============================] - 309s 1s/step - loss: 0.0109 - get_jaccard_index: 0.9970 - val_loss: 0.0170 - val_get_jaccard_index: 0.9963
# Epoch 3/100
# 285/285 [==============================] - 313s 1s/step - loss: 0.0073 - get_jaccard_index: 0.9979 - val_loss: 0.1687 - val_get_jaccard_index: 0.8835
# Epoch 4/100
# 285/285 [==============================] - 309s 1s/step - loss: 0.0037 - get_jaccard_index: 0.9985 - val_loss: 0.0140 - val_get_jaccard_index: 0.9988
# Epoch 5/100
# 285/285 [==============================] - 309s 1s/step - loss: 0.0029 - get_jaccard_index: 0.9988 - val_loss: 0.0145 - val_get_jaccard_index: 0.9989
# Epoch 6/100
# 285/285 [==============================] - 312s 1s/step - loss: 0.0025 - get_jaccard_index: 0.9990 - val_loss: 0.0158 - val_get_jaccard_index: 0.9974
# Epoch 7/100
# 285/285 [==============================] - 311s 1s/step - loss: 0.0021 - get_jaccard_index: 0.9992 - val_loss: 0.0152 - val_get_jaccard_index: 0.9990
# Epoch 8/100
# 285/285 [==============================] - 313s 1s/step - loss: 0.0018 - get_jaccard_index: 0.9993 - val_loss: 0.0178 - val_get_jaccard_index: 0.9989
# Epoch 9/100
# 285/285 [==============================] - 311s 1s/step - loss: 0.0016 - get_jaccard_index: 0.9994 - val_loss: 0.7790 - val_get_jaccard_index: 0.7532
# Epoch 10/100
# 285/285 [==============================] - 308s 1s/step - loss: 0.0013 - get_jaccard_index: 0.9995 - val_loss: 0.0104 - val_get_jaccard_index: 0.9990
# Epoch 11/100
# 285/285 [==============================] - 309s 1s/step - loss: 0.0013 - get_jaccard_index: 0.9995 - val_loss: 0.0116 - val_get_jaccard_index: 0.9991
# Epoch 12/100
# 285/285 [==============================] - 308s 1s/step - loss: 9.2497e-04 - get_jaccard_index: 0.9996 - val_loss: 0.0127 - val_get_jaccard_index: 0.9992
# Epoch 13/100
# 285/285 [==============================] - 307s 1s/step - loss: 0.0012 - get_jaccard_index: 0.9996 - val_loss: 0.0105 - val_get_jaccard_index: 0.9986
# Epoch 14/100
# 285/285 [==============================] - 307s 1s/step - loss: 7.9652e-04 - get_jaccard_index: 0.9997 - val_loss: 0.0121 - val_get_jaccard_index: 0.9990
# Epoch 15/100
# 285/285 [==============================] - 308s 1s/step - loss: 0.0013 - get_jaccard_index: 0.9996 - val_loss: 0.0146 - val_get_jaccard_index: 0.9992
# Epoch 16/100
# 285/285 [==============================] - 307s 1s/step - loss: 0.0010 - get_jaccard_index: 0.9996 - val_loss: 0.0125 - val_get_jaccard_index: 0.9992
# Epoch 17/100
# 285/285 [==============================] - 308s 1s/step - loss: 9.0130e-04 - get_jaccard_index: 0.9997 - val_loss: 0.0137 - val_get_jaccard_index: 0.9992
# Epoch 18/100
# 285/285 [==============================] - 308s 1s/step - loss: 7.0395e-04 - get_jaccard_index: 0.9997 - val_loss: 0.0135 - val_get_jaccard_index: 0.9993
# Epoch 19/100
# 285/285 [==============================] - 309s 1s/step - loss: 6.0361e-04 - get_jaccard_index: 0.9998 - val_loss: 0.0137 - val_get_jaccard_index: 0.9988
# Epoch 20/100
# 285/285 [==============================] - 308s 1s/step - loss: 6.3211e-04 - get_jaccard_index: 0.9998 - val_loss: 0.0166 - val_get_jaccard_index: 0.9992
# Epoch 21/100
# 285/285 [==============================] - 309s 1s/step - loss: 5.1584e-04 - get_jaccard_index: 0.9998 - val_loss: 0.0157 - val_get_jaccard_index: 0.9992
# Epoch 22/100
# 285/285 [==============================] - 308s 1s/step - loss: 5.3896e-04 - get_jaccard_index: 0.9998 - val_loss: 0.0171 - val_get_jaccard_index: 0.9990
# Epoch 23/100
# 285/285 [==============================] - 315s 1s/step - loss: 7.3551e-04 - get_jaccard_index: 0.9997 - val_loss: 0.0150 - val_get_jaccard_index: 0.9993
# Epoch 24/100
# 285/285 [==============================] - 308s 1s/step - loss: 5.0269e-04 - get_jaccard_index: 0.9998 - val_loss: 0.0139 - val_get_jaccard_index: 0.9993
# Epoch 25/100
# 285/285 [==============================] - 308s 1s/step - loss: 4.0252e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0172 - val_get_jaccard_index: 0.9992
# Epoch 26/100
# 285/285 [==============================] - 308s 1s/step - loss: 4.3923e-04 - get_jaccard_index: 0.9998 - val_loss: 0.0150 - val_get_jaccard_index: 0.9993
# Epoch 27/100
# 285/285 [==============================] - 308s 1s/step - loss: 4.5673e-04 - get_jaccard_index: 0.9998 - val_loss: 0.0139 - val_get_jaccard_index: 0.9993
# Epoch 28/100
# 285/285 [==============================] - 308s 1s/step - loss: 3.5646e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0161 - val_get_jaccard_index: 0.9987
# Epoch 29/100
# 285/285 [==============================] - 308s 1s/step - loss: 3.4955e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0159 - val_get_jaccard_index: 0.9993
# Epoch 30/100
# 285/285 [==============================] - 312s 1s/step - loss: 3.7145e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0165 - val_get_jaccard_index: 0.9993
# Epoch 31/100
# 285/285 [==============================] - 309s 1s/step - loss: 3.3026e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0143 - val_get_jaccard_index: 0.9992
# Epoch 32/100
# 285/285 [==============================] - 309s 1s/step - loss: 3.6671e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0188 - val_get_jaccard_index: 0.9992
# Epoch 33/100
# 285/285 [==============================] - 319s 1s/step - loss: 4.5455e-04 - get_jaccard_index: 0.9999 - val_loss: 0.1610 - val_get_jaccard_index: 0.9348
# Epoch 34/100
# 285/285 [==============================] - 308s 1s/step - loss: 0.0012 - get_jaccard_index: 0.9996 - val_loss: 0.0136 - val_get_jaccard_index: 0.9993
# Epoch 35/100
# 285/285 [==============================] - 308s 1s/step - loss: 4.5490e-04 - get_jaccard_index: 0.9998 - val_loss: 0.0123 - val_get_jaccard_index: 0.9993
# Epoch 36/100
# 285/285 [==============================] - 308s 1s/step - loss: 3.7704e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0139 - val_get_jaccard_index: 0.9993
# Epoch 37/100
# 285/285 [==============================] - 308s 1s/step - loss: 3.0806e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0151 - val_get_jaccard_index: 0.9993
# Epoch 38/100
# 285/285 [==============================] - 308s 1s/step - loss: 2.9569e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0146 - val_get_jaccard_index: 0.9993
# Epoch 39/100
# 285/285 [==============================] - 309s 1s/step - loss: 2.7188e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0156 - val_get_jaccard_index: 0.9993
# Epoch 40/100
# 285/285 [==============================] - 309s 1s/step - loss: 2.9991e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0153 - val_get_jaccard_index: 0.9993
# Epoch 41/100
# 285/285 [==============================] - 317s 1s/step - loss: 2.8444e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0140 - val_get_jaccard_index: 0.9993
# Epoch 42/100
# 285/285 [==============================] - 308s 1s/step - loss: 2.6954e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0169 - val_get_jaccard_index: 0.9993
# Epoch 43/100
# 285/285 [==============================] - 308s 1s/step - loss: 2.4263e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0159 - val_get_jaccard_index: 0.9993
# Epoch 44/100
# 285/285 [==============================] - 307s 1s/step - loss: 2.4227e-04 - get_jaccard_index: 0.9999 - val_loss: 0.1066 - val_get_jaccard_index: 0.9735
# Epoch 45/100
# 285/285 [==============================] - 308s 1s/step - loss: 3.0314e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0171 - val_get_jaccard_index: 0.9993
# Epoch 46/100
# 285/285 [==============================] - 308s 1s/step - loss: 2.3049e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0165 - val_get_jaccard_index: 0.9993
# Epoch 47/100
# 285/285 [==============================] - 308s 1s/step - loss: 2.1171e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0150 - val_get_jaccard_index: 0.9994
# Epoch 48/100
# 285/285 [==============================] - 308s 1s/step - loss: 2.7399e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0182 - val_get_jaccard_index: 0.9992
# Epoch 49/100
# 285/285 [==============================] - 308s 1s/step - loss: 2.4344e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0165 - val_get_jaccard_index: 0.9993
# Epoch 50/100
# 285/285 [==============================] - 308s 1s/step - loss: 2.4320e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0156 - val_get_jaccard_index: 0.9993
# Epoch 51/100
# 285/285 [==============================] - 308s 1s/step - loss: 2.0375e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0171 - val_get_jaccard_index: 0.9993
# Epoch 52/100
# 285/285 [==============================] - 308s 1s/step - loss: 5.9244e-04 - get_jaccard_index: 0.9998 - val_loss: 0.0169 - val_get_jaccard_index: 0.9992
# Epoch 53/100
# 285/285 [==============================] - 307s 1s/step - loss: 2.6455e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0139 - val_get_jaccard_index: 0.9993
# Epoch 54/100
# 285/285 [==============================] - 307s 1s/step - loss: 2.2885e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0160 - val_get_jaccard_index: 0.9993
# Epoch 55/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.9335e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0166 - val_get_jaccard_index: 0.9993
# Epoch 56/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.8303e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0160 - val_get_jaccard_index: 0.9994
# Epoch 57/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.8172e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0184 - val_get_jaccard_index: 0.9993
# Epoch 58/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.7199e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0176 - val_get_jaccard_index: 0.9994
# Epoch 59/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.7150e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0173 - val_get_jaccard_index: 0.9994
# Epoch 60/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.5793e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0189 - val_get_jaccard_index: 0.9993
# Epoch 61/100
# 285/285 [==============================] - 307s 1s/step - loss: 9.1033e-04 - get_jaccard_index: 0.9997 - val_loss: 0.0175 - val_get_jaccard_index: 0.9992
# Epoch 62/100
# 285/285 [==============================] - 307s 1s/step - loss: 2.5939e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0168 - val_get_jaccard_index: 0.9993
# Epoch 63/100
# 285/285 [==============================] - 307s 1s/step - loss: 2.1853e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0171 - val_get_jaccard_index: 0.9993
# Epoch 64/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.7245e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0178 - val_get_jaccard_index: 0.9993
# Epoch 65/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.7243e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0182 - val_get_jaccard_index: 0.9993
# Epoch 66/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.5439e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0198 - val_get_jaccard_index: 0.9993
# Epoch 67/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.5435e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0194 - val_get_jaccard_index: 0.9993
# Epoch 68/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.5569e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0277 - val_get_jaccard_index: 0.9988
# Epoch 69/100
# 285/285 [==============================] - 307s 1s/step - loss: 6.7318e-04 - get_jaccard_index: 0.9998 - val_loss: 0.0161 - val_get_jaccard_index: 0.9993
# Epoch 70/100
# 285/285 [==============================] - 307s 1s/step - loss: 2.2537e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0166 - val_get_jaccard_index: 0.9993
# Epoch 71/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.8169e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0182 - val_get_jaccard_index: 0.9993
# Epoch 72/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.5663e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0177 - val_get_jaccard_index: 0.9993
# Epoch 73/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.5654e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0182 - val_get_jaccard_index: 0.9993
# Epoch 74/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.5079e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0194 - val_get_jaccard_index: 0.9993
# Epoch 75/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.3597e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0192 - val_get_jaccard_index: 0.9993
# Epoch 76/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.3849e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0194 - val_get_jaccard_index: 0.9993
# Epoch 77/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.3055e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0196 - val_get_jaccard_index: 0.9993
# Epoch 78/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.3127e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0200 - val_get_jaccard_index: 0.9993
# Epoch 79/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.2401e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0192 - val_get_jaccard_index: 0.9993
# Epoch 80/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.4489e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0193 - val_get_jaccard_index: 0.9993
# Epoch 81/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.3070e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0172 - val_get_jaccard_index: 0.9992
# Epoch 82/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.5548e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0191 - val_get_jaccard_index: 0.9992
# Epoch 83/100
# 285/285 [==============================] - 307s 1s/step - loss: 5.1193e-04 - get_jaccard_index: 0.9998 - val_loss: 0.0135 - val_get_jaccard_index: 0.9993
# Epoch 84/100
# 285/285 [==============================] - 307s 1s/step - loss: 2.0660e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0184 - val_get_jaccard_index: 0.9992
# Epoch 85/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.6676e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0167 - val_get_jaccard_index: 0.9993
# Epoch 86/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.2908e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0189 - val_get_jaccard_index: 0.9993
# Epoch 87/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.2307e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0198 - val_get_jaccard_index: 0.9993
# Epoch 88/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.1396e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0200 - val_get_jaccard_index: 0.9991
# Epoch 89/100
# 285/285 [==============================] - 307s 1s/step - loss: 1.4531e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0189 - val_get_jaccard_index: 0.9993
# Epoch 90/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.1609e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0168 - val_get_jaccard_index: 0.9994
# Epoch 91/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.0669e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0198 - val_get_jaccard_index: 0.9993
# Epoch 92/100
# 285/285 [==============================] - 309s 1s/step - loss: 9.0488e-04 - get_jaccard_index: 0.9998 - val_loss: 0.0176 - val_get_jaccard_index: 0.9993
# Epoch 93/100
# 285/285 [==============================] - 308s 1s/step - loss: 2.6011e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0173 - val_get_jaccard_index: 0.9993
# Epoch 94/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.8603e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0176 - val_get_jaccard_index: 0.9993
# Epoch 95/100
# 285/285 [==============================] - 309s 1s/step - loss: 1.5084e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0178 - val_get_jaccard_index: 0.9993
# Epoch 96/100
# 285/285 [==============================] - 309s 1s/step - loss: 1.4199e-04 - get_jaccard_index: 0.9999 - val_loss: 0.0180 - val_get_jaccard_index: 0.9993
# Epoch 97/100
# 285/285 [==============================] - 308s 1s/step - loss: 1.2602e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0186 - val_get_jaccard_index: 0.9993
# Epoch 98/100
# 285/285 [==============================] - 309s 1s/step - loss: 1.2462e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0187 - val_get_jaccard_index: 0.9993
# Epoch 99/100
# 285/285 [==============================] - 309s 1s/step - loss: 1.2040e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0182 - val_get_jaccard_index: 0.9993
# Epoch 100/100
# 285/285 [==============================] - 309s 1s/step - loss: 1.0864e-04 - get_jaccard_index: 1.0000 - val_loss: 0.0189 - val_get_jaccard_index: 0.9993
# Unexpected error in ping thread.
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/urllib3/connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/urllib3/connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/urllib3/connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/http/client.py", line 1369, in getresponse
#     response.begin()
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/http/client.py", line 310, in begin
#     version, status, reason = self._read_status()
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/http/client.py", line 271, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/urllib3/connectionpool.py", line 756, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/urllib3/util/retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/urllib3/packages/six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/urllib3/connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/urllib3/connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/urllib3/connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/http/client.py", line 1369, in getresponse
#     response.begin()
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/http/client.py", line 310, in begin
#     version, status, reason = self._read_status()
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/http/client.py", line 271, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# urllib3.exceptions.ProtocolError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/bravado/http_future.py", line 124, in wrapper
#     return func(self, *args, **kwargs)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/bravado/http_future.py", line 291, in _get_incoming_response
#     inner_response = self.future.result(timeout=timeout)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/bravado/requests_client.py", line 270, in result
#     **settings
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/requests/adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/neptune/internal/threads/ping_thread.py", line 37, in run
#     self.__backend.ping_experiment(self.__experiment)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/neptune/internal/api_clients/hosted_api_clients/hosted_alpha_leaderboard_api_client.py", line 392, in ping_experiment
#     self.leaderboard_swagger_client.api.ping(experimentId=str(experiment.internal_id)).response().result
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/bravado/http_future.py", line 239, in response
#     six.reraise(*sys.exc_info())
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/six.py", line 719, in reraise
#     raise value
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/bravado/http_future.py", line 197, in response
#     incoming_response = self._get_incoming_response(timeout)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/bravado/http_future.py", line 126, in wrapper
#     self.future._raise_connection_error(exception)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/bravado/http_future.py", line 91, in _raise_connection_error
#     self._raise_error(BravadoConnectionError, 'ConnectionError', exception)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/bravado/http_future.py", line 82, in _raise_error
#     sys.exc_info()[2],
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/six.py", line 718, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/bravado/http_future.py", line 124, in wrapper
#     return func(self, *args, **kwargs)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/bravado/http_future.py", line 291, in _get_incoming_response
#     inner_response = self.future.result(timeout=timeout)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/bravado/requests_client.py", line 270, in result
#     **settings
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/usr/local/anaconda3/envs/PhD_clone_env/lib/python3.7/site-packages/requests/adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# bravado.http_future.RequestsFutureAdapterConnectionError
